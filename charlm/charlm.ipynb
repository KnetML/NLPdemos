# %% [markdown]
# # Character based RNN language model
# Based on http://karpathy.github.io/2015/05/21/rnn-effectiveness

# %%
include("charlm.jl")
# Out:
# INFO: Loading Shakespeare data
# INFO: Loading Shakespeare model
# INFO: Reading Julia files
# INFO: Loading Julia model

# %%
# A random subset of the Shakespeare training data
LEN = 500
r = rand(1:length(shake_text)-LEN)
println(shake_text[r:r+LEN])
# Out:
# s prodigal of all dear grace
#     As Nature was in making graces dear,
#     When she did starve the general world beside
#     And prodigally gave them all to you.
#   PRINCESS OF FRANCE. Good Lord Boyet, my beauty, though but mean,
#     Needs not the painted flourish of your praise.
#     Beauty is bought by judgment of the eye,
#     Not utt'red by base sale of chapmen's tongues;
#     I am less proud to hear you tell my worth
#     Than you much willing to be counted wise
#     In spending your wit

# %%
# Random Shakespeare style text generated by the model
generate(shake_model, LEN)
# Out:
#                                   No; for ill contrive; I will not,
#     Why something of Rome I'll think condemney
#     His paix upon a rootest by thee;
#     And too, therefore they shall dine him, I will charg'd,
#     That freely here, and there rul'st to hanghom
#     On, a mind'st corn, and execution deserves,
#     For the next to his wolf, and cry boy'd to,
#     He shall ure in Points with the caps of good;
#     And yet are stones but thy glies, and swiarding me in
#     The poisonal thrice,

# %%
# A random subset of the code in Julia base
r = rand(1:length(julia_text)-LEN)
println(julia_text[r:r+LEN])
# Out:
# wing for no adjustment to occur.
# """
# tonext(dt::TimeType, dow::Int; same::Bool=false) = adjust(ISDAYOFWEEK[dow], same ? dt : dt + Day(1), Day(1), 7)
#
# # Return the next TimeType where func evals true using step in incrementing
# """
#     tonext(func::Function, dt::TimeType; step=Day(1), limit=10000, same=false) -> TimeType
#
# Adjusts `dt` by iterating at most `limit` iterations by `step` increments until `func`
# returns `true`. `func` must take a single `TimeType` argument and return a [`Bool`](@ref).
# `

# %%
# Random Julia code generated by the model
generate(julia_model, LEN)
# Out:
#     Y = Set(",+ ())
#     len = copy(A)
#     return Where T
#     @inbounds for i = 1:n
#         t = p + a == b[jata
#         x = if lt(o, v[1], v[2])
#             v = op(f, f()
#             for i = 1:n-1
#                 B[i,i] = u
#             end
#         end
#     end
#     return y
# end
#
# function size(M::Bidiagonal)
#     T = promote_type(Float64, typeof(zero(T)/norm(one(T))))
#     eigmax(x, tril!(B), B)
#     #endsubtract!(A::StridedMatrix{<:BlasReal}, B::StridedMatrix{T}) where T
#     for k = 1:n
#         for i
